# %%
import numpy as np
import skimage as ski
import skimage.io as io

import os

# %%
# Since binary file represents only pixel values, information about image shape
# width and height is needed for correct image representation.

def read_bin_img(file_name, img_shape, type = 'uint8'):
    if (type == 'uint8' or type == 'uint16' or type == 'uint32'):
        input_data = np.fromfile(file_name, dtype=type, offset=0)
    else:
        return -1
        
    img_in = np.reshape(input_data, (img_shape[1],img_shape[0]))
    
    return img_in

def write_bin_img(file_name, img_out, type = 'uint8'):
    file_out = open(file_name, 'wb')
    if (type == 'uint8'):
        file_out.write(np.uint8(img_out.flatten()))
    elif (type == 'uint16'):
        file_out.write(np.uint16(img_out.flatten()))
    elif (type == 'uint32'):
        file_out.write(np.uint32(img_out.flatten()))
    else:
        return -1
 
    file_out.close()

# %%
input_data = np.fromfile('lena_128.bin', dtype=np.uint8)
input_data = input_data[8:]
img = input_data.reshape((128, 128))
ski.io.imshow(img);
# Out:
# <ipython-input-13-790f68aead1f>:4: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('lena_128_processed.bin', [128,128])
ski.io.imshow(img);

print(img.shape)
# Out:
# <ipython-input-7-530413c0aa5a>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
# (128, 128)

# %%
img = read_bin_img('lena_128_processed_hw.bin', [128,128])
ski.io.imshow(img);

print(img.shape)
# Out:
# <ipython-input-10-88ea7f259baf>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
# (128, 128)

# %%
img = read_bin_img('new1/lena_128_processed_sw_4.bin', [128,128])
ski.io.imshow(img);

print(img.shape)
# Out:
# <ipython-input-6-d99146885c90>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
# (128, 128)

# %%
img = read_bin_img('new1/lena_128_processed_hw_4.bin', [128, 128])
ski.io.imshow(img);

print(img.shape)
# Out:
# <ipython-input-7-49b8faf0bca7>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
# (128, 128)

# %%
img = read_bin_img('new1/lena_128_processed_hw_5.bin', [128,256])
ski.io.imshow(img);
print(img.shape)
# Out:
# <ipython-input-27-9d8314d40ebe>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
# (256, 128)

# %%
img = read_bin_img('new1/lena_128_processed_hw_5.bin', [128,256])

ski.io.imshow(img);
# Out:
# <ipython-input-46-b8c23bcd5877>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new1/lena_128_processed_hw_7.bin', [256,256])
ski.io.imshow(img);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 img = read_bin_img('new1/lena_128_processed_hw_7.bin', [256,128])
#       2 ski.io.imshow(img);
#
# Cell In[2], line 10, in read_bin_img(file_name, img_shape, type)
#       7 else:
#       8     return -1
# ---> 10 img_in = np.reshape(input_data, (img_shape[1],img_shape[0]))
#      12 return img_in
#
# File /lib/python3.13/site-packages/numpy/_core/fromnumeric.py:324, in reshape(a, shape, order, newshape, copy)
#     322 if copy is not None:
#     323     return _wrapfunc(a, 'reshape', shape, order=order, copy=copy)
# --> 324 return _wrapfunc(a, 'reshape', shape, order=order)
#
# File /lib/python3.13/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
# ...

# %%
img = read_bin_img('new1/lena_128_processed_hw.bin', [128,64], 'uint16')
ski.io.imshow(img);
# Out:
# <ipython-input-48-b4401c674a13>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
# /lib/python3.13/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
img = read_bin_img('new1/lena_128_processed_hw3.bin', [256,256])
ski.io.imshow(img);
# Out:
# <ipython-input-61-4aa6a9245a78>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new3/lena_128_processed_sw.bin', [128,128])
ski.io.imshow(img);
# Out:
# <ipython-input-47-b20d03402b06>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new3/lena_128_processed_hw.bin', [128,128])
ski.io.imshow(img);
# Out:
# <ipython-input-76-ff0c204d8582>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new3/lena_128_processed_hw_0.bin', [128, 128])
ski.io.imshow(img);
# Out:
# <ipython-input-78-40560a52f62e>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new3/lena_128_processed_hw_7x7_16.bin', [128, 128], 'uint16')
ski.io.imshow(img);
# Out:
# <ipython-input-68-5d9c476c098a>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new3/lena_128_processed_sw_7x7_16.bin', [128, 128], 'uint16')
ski.io.imshow(img);
# Out:
# <ipython-input-69-aa51999b2993>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new4/lena_128_processed_hw_3x3.bin', [128, 128])

ski.io.imshow(img);
# Out:
# <ipython-input-79-32e632f5586d>:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
io.imsave("slike/lena128_3x3_hw.png", img)

# %%
def remove_first_bytes(file_path, n=8):
    """Remove first n bytes from a binary file, overwrite in place."""
    with open(file_path, 'rb') as f:
        data = f.read()
    with open(file_path, 'wb') as f:
        f.write(data[n:])
    print(f"Removed first {n} bytes from {file_path}")
    
remove_first_bytes('lena_128.bin', n=8)
# Out:
# Removed first 8 bytes from lena_128.bin

# %%
img = read_bin_img('lena_128.bin', [128, 128])

ski.io.imshow(img);
# Out:
# <ipython-input-122-e041ae17f169>:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new4/lena_128_processed_sw_3x3_bypass_16.bin', [128, 128], 'uint16')

ski.io.imshow(img);
io.imsave("slike/lena128_sw_3x3_bypass_16.png", img)
# Out:
# <ipython-input-149-1d7902c3de4c>:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);

# %%
img = read_bin_img('new4/lena_128_processed_hw_3x3_bypass_16.bin', [128, 128], 'uint16')

ski.io.imshow(img);
io.imsave("slike/lena128_hw_3x3_bypass_16.png", img)
# Out:
# <ipython-input-148-023b1e8dbaca>:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(img);
